# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading CSV file

# %%
data=pd.read_csv('Research.csv')

# %% [markdown]
# # Printing all data values

# %%
data
# Out:
#              Timestamp              Name  Age      Sex  \
# 0     6/9/2020 9:42:57     Vishant tyagi   19     Male
# 1     6/9/2020 9:48:32           Vishant   19     Male
# 2     6/9/2020 9:50:12       Karan Singh   20     Male
# 3    6/9/2020 10:10:48    Abhishek sinha   21     Male
# 4    6/9/2020 10:16:48        Yash Tyagi   19     Male
# 5    6/9/2020 10:18:53       Abhay singh   19     Male
# 6    6/9/2020 10:22:29       Rohit gupta   21    Male
# 7    6/9/2020 10:26:34           Piyush    19     Male
# 8    6/9/2020 10:37:37          Akanksha   20   Female
# 9    6/9/2020 10:38:35           Vaibhav   21     Male
# 10   6/9/2020 10:40:34           Akansha   17   Female
# 11   6/9/2020 10:41:00       Jyoti Singh   18   Female
# 12   6/9/2020 10:43:14      Ritesh Kumar   19     Male
# 13   6/9/2020 10:46:07   Shivendra Singh   18     Male
# 14   6/9/2020 10:51:20       Naman Dabas   20     Male
# 15   6/9/2020 10:57:50      Prachi lakra   21   Female
# ...

# %% [markdown]
# # Few analysis using crosstab function

# %% [markdown]
# # 1.

# %%
pd.crosstab(data.iloc[:,12], data.iloc[:, 13])
# Out:
# Is there any Relaxation given to students in terms of fees?  No  yes
# will this lockdown affect the placement session...
# no                                                           23    2
# yes                                                          21    6

# %% [markdown]
# # 2.

# %%
pd.crosstab(data.iloc[:,14], data.iloc[:, 15])
# Out:
# will exam be conducted ?                            No  yes
# will this lockdown affect the academics grades ...
# No                                                  26    3
# yes                                                 17    6

# %% [markdown]
# # Probability calculated for each condition

# %%
from math import pi

Pindia=pi*phyi*payi

print(Pindia)
